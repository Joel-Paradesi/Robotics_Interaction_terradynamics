# %%
# Cell 1 — install condacolab (causes runtime restart)
# !pip install condacolab -q
import condacolab; condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1068/4276358371.py in <cell line: 0>()
#       1 # Cell 1 — install condacolab (causes runtime restart)
#       2 get_ipython().system('pip install condacolab -q')
# ----> 3 import condacolab; condacolab.install()
#
# /usr/local/lib/python3.12/dist-packages/condacolab.py in install_miniforge(prefix, env, run_checks)
#     205     )
#     206     checksum = "359f81e4bc706c3e237105cc42cb5d5deaee0c89b4391cb70c5cb2c27d4e3677"
# --> 207     install_from_url(
#     208         installer_url, prefix=prefix, env=env, run_checks=run_checks, sha256=checksum
#     209     )
#
# ...

# %%
# Cell 2 — install PyChrono after restart
# !conda install -c projectchrono pychrono -y -q
# Out:
# Channels:
#  - projectchrono
#  - conda-forge
# Platform: linux-64
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
# Cell 3 — run the sim
exec(open("chrono_sand_robot_sim.py").read())
# Out:
# ⚠  PyChrono not found — running analytical / plotting mode only.
#    (Install with:  conda install -c projectchrono pychrono)
#
# ════════════════════════════════════════════════════════════════════════
#  PyChrono Legged-Robot × Deformable-Terrain Simulation
#  Soil    : Coarse Sand
#  Foot    : Plastic  (R=3.0 cm)
#  FN      : 60.0 N
#  PyChrono: DISABLED — analytical mode
#  Output  : /content
# ════════════════════════════════════════════════════════════════════════
#
# [1/4] Terramechanics summary …
#   Saved → terramechanics_summary.png
#
# [2/4] Normal load sweep …
#   Saved → normal_load_sweep.png
#
# [3/4] SIM-1 foot–terrain interaction (analytical) …
#   [SIM-1] PyChrono unavailable — returning synthetic data for plotting.
#   Saved → sim1_foot_terrain.png
#
# [4/4] SIM-2 tripod robot (analytical) …
#   [SIM-2] PyChrono unavailable — returning synthetic data.
#   Saved → sim2_robot.png
#
# ════════════════════════════════════════════════════════════════════════
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1068/983858508.py in <cell line: 0>()
# ----> 1 import pychrono as chrono
#       2 import pychrono.gpu as gpu
#       3 import numpy as np
#       4 import matplotlib.pyplot as plt
#       5
#
# ModuleNotFoundError: No module named 'pychrono'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
